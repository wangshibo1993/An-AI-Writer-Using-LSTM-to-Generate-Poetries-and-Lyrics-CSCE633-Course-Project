# %%
# python3
# -*- coding: utf-8 -*-
"""
主要是对歌词进行处理，将所有歌词拼接到一个文件中，并将以下无用数据去除：
1、空行
2、特殊字开头：
    ["编曲", "编辑", "歌名", "歌手", "专辑", "木吉他", "贝斯", "发行日", "曲", "监制", "制作人", "中乐演奏", "其余所有乐器演奏", "演奏", "和音",
                 "联合制作", "制作", "录音", "混音", "录音室", "混音室", "录音师", "混音师", "统筹", "制作统筹", "执行制作", "母带后期处理", "企划", "鼓",
                 "合声", "二胡", "乌克丽丽", "过带", "Bass", "Scratch", "OP", "Guitar", "SP", "Bass", "SCRATCH", "Programmer", "弦乐", "小提琴",
                 "女声", "Cello solo", "Piano", "吉他", "钢琴", "os", "弦乐", "和声", "DJ", "Tibet", "Violin", "Viola", "Cello", "和声", "母带",
                 "音乐", "打击乐", "Vocal", "次中音", "长号", "小号", "Music", "监制", "作词", "词/曲", "箫", "筝", "作词", "作曲", "Program", "键盘", "制作"]
3、将标点符号去除
"""
import os
import re

def handleLyrics(fPath, del_words):
    """
    对歌词进行处理。注意为了在seq2seq模型中使用，所以在每一首歌词后面添加一个换行
    :param fPath: 歌词文件夹路径
    :param del_words: 需要去掉的内容
    :return:
    """
    files_name = os.listdir(fPath)
    print("len of files_name::", len(files_name))
    for file_name in files_name:
        print(file_name)
    
    with open("./xiba.txt", 'a', encoding='utf8') as w:
        for file_name in files_name:
            flag_contain = 0    # 此文件是否包含歌词信息，若为空，则不需要最后添加空行
            with open(fPath + '/' + file_name, 'r', encoding='utf8') as f:
                lines = f.readlines()
                for line in lines:
                    flag_del = 0    # 此行是否需要去除
                    for del_word in del_words:
                        if del_word in line:
                            flag_del = 1    # 若有“作词”等开头的句子，说明不是歌词，则直接将此行去掉
                            break
                    if flag_del == 1:
                            continue
                    space_except_char = """
                    """   # 爬取到的特殊的换行符，注意：此符号不是“\n”
                    # 若一句话中含有特殊符号，则使用特殊符号分割
                    line_splits = [elem for elem in re.split(r'[ \s+_+#-:：.\?"\(\),~.。、，…？「」【】（）{}+=\u3000\n]', re.sub("[A-Za-z0-9]", "", line.replace(space_except_char, '')).strip()) if elem != "" and elem !='\n' and elem != '\r\n']
                    for line_split in line_splits:
                        if line_split.strip() != '' and line_split.strip() !='\r\n':
                            flag_contain = 1
                            w.write(line_split.strip() + " ")
            f.close()
            if flag_contain == 1:   # 每首歌最后添加一个空行
                w.write("\n")
    w.close()

# %%
fPath = "./Lyrics"   # dataCrawling.py爬取结果的路径。可以先处理下，比如将乱七八糟的句子去除等，所以这里文件名是处理过的爬取数据目录。
del_words = ["编曲", "视频", "音频", "作曲", "策划", "后期", "原作", "混音", "编辑", "间奏", "歌名", "歌手", "专辑", "木吉他", "贝斯", "发行日", "曲", "监制", "制作人", "中乐演奏", "其余所有乐器演奏", "演奏", "和音",
                 "联合制作", "制作", "录音", "混音", "录音室", "混音室", "录音师", "混音师", "统筹", "制作统筹", "执行制作", "母带后期处理", "企划", "鼓",
                 "合声", "二胡", "乌克丽丽", "过带", "Bass", "Scratch", "OP", "Guitar", "SP", "Bass", "SCRATCH", "Programmer", "弦乐", "小提琴", "PV", "原画", "海报",
                 "女声", "Cello solo", "Piano", "吉他", "钢琴", "os", "弦乐", "和声", "DJ", "Tibet", "Violin", "Viola", "Cello", "和声", "母带",
                 "音乐", "打击乐", "Vocal", "次中音", "长号", "小号", "Music", "监制", "作词", "词/曲", "箫", "筝", "作词", "作曲", "Program", "键盘", "制作"]
handleLyrics(fPath, del_words)
# Out:
# len of files_name:: 1165
# .txt
# 2018～朝你靠近～（Cover 初音ミク）.txt
# Blessing - 女声版.txt
# Connecting【中文填词】（Cover 初音）.txt
# It's My Life.txt
# PLANET（Cover ラムジ）.txt
# RAP版自挂东南枝.txt
# Remember Me（Cover COCO）.txt
# Shape of you（Cover Ed Sheeran）.txt
# Tacke竹桑-情炽.txt
# We Don't Talk Anymore（Cover Charlie Puth&Selena Gomez）.txt
# Whataya want from me.txt
# Zodiac~黄道十二宫.txt
# [剑三] 斩思.txt
# βιοζ-δ - 双声道版.txt
# 《2016～谢谢陌生的你～》（32P）.txt
# 《2017～陪你到世界尽头～》（31P）.txt
# 《众神的舞台》全职高手同人曲.txt
# 《在风里》（【恋与制作人】——白起原创同人歌曲）.txt
# 《大鱼海棠》印象曲《大鱼》.txt
# 《如愿》烈火如歌手游同人歌.txt
# 《年岁予我》with.男神女神们.txt
# 《江山为祭》.txt
# 《牵机》——剑网3唐门五毒门派同人原创主题曲.txt
# 《画江湖之侠岚》主题曲-—述岚记.txt
# 《虎啸龙吟》——《大军师司马懿之虎啸龙吟》电视剧同人曲.txt
# 《魔道祖师》群像——临歧久别歌（剧情版）.txt
# 『翻唱』老街.txt
# 【22只】2012～放肆喧嚣～.txt
# 【24只】2014～唱于你听～.txt
# 【24只】2015～不屑言败～.txt
# 【31只】2017～陪你到世界尽头～.txt
# 【32p】2016～谢谢陌生的你～（Cover 温岚）.txt
# 【32只】2016～谢谢陌生的你～.txt
# 【34只】2018～朝你靠近～.txt
# 【3D】We Don't Talk Anymore.txt
# 【Moonlight】合格男友.txt
# 【佛秀】说不得.txt
# 【入梦】竹梦令.txt
# 【全职·国家队群像】苏黎世见（念白版）.txt
# 【全职同人】荣耀·征途（Cover 流月《混沌》）.txt
# 【全职高手】天之厚我.txt
# 【全职高手原创】一战成名.txt
# 【剑三】安史·乱世浮殇【剧情版】.txt
# 【剑网3】依山观澜(藏剑·叶英).txt
# 【剑网3】千载名(王遗风&谢渊).txt
# 【剑网3】烽火入冬来(天策).txt
# 【剑网3】禅心通明(七秀&少林).txt
# 【剑网3八周年原创】《春秋侠客》纯歌版.txt
# 【原创】醉宿州.txt
# 【大国手】广陵老（Cover 花好月圆夜）.txt
# 【排骨xPayam1】东京不太热.txt
# 【排骨xPayam1】干物女（weiwei）.txt
# 【排骨xPayam1】走在冷风中.txt
# 【排骨x西瓜JUN】锦鲤抄.txt
# 【渣反】青衫白首——记沈九【弧光x小旭pro】.txt
# 【魔兽】亡灵序曲live版.txt
# 【魔道祖师】同道殊途（剧情版）.txt
# 【魔道祖师】君子如故.txt
# 【魔道祖师】归客天涯.txt
# 【魔道祖师群像】几忆年少共酩酊.txt
# 一世妆.txt
# 一世长安.txt
# 一人我饮酒醉古风版.txt
# 一任旧风华.txt
# 一剑轻安.txt
# 一剑霜寒—剑网三浩气同人歌.txt
# 一念（手游《镇魔曲》主题曲）.txt
# 一战成名（燃向，5P同人歌）——【全职高手同人曲】.txt
# 一战破晓.txt
# 一时多少豪杰（念白版）——【收录于专辑《依稀故人来》】.txt
# 一梦浮生 — 天涯明月刀OL群像.txt
# 一梦青丘.txt
# 一生一刹.txt
# 一眼旧梦.txt
# 一纸流年.txt
# 一般般.txt
# 一行.txt
# 一身诗意千寻瀑.txt
# 一身诗意千寻瀑（演唱：贰婶）.txt
# 一醉南柯.txt
# 一首想不通的古风.txt
# 七夕.txt
# 七日札.txt
# 万古人间四月天.txt
# 万物生.txt
# 万神纪【男男互攻燃到爆】（Cover 肥皂菌）.txt
# 万神纪古风抒情版.txt
# 万般徒说.txt
# 三世.txt
# 三世缘.txt
# 三月雨.txt
# 三生叹.txt
# 三生石三生路.txt
# 上元.txt
# 上邪.txt
# 不屑言败.txt
# 不开口的花.txt
# 不归人.txt
# 不悔.txt
# 不是桃源曾归处(剧情版).txt
# 不期而遇的温暖.txt
# 不朽之罪（ft.双笙）重编曲.txt
# 不染.txt
# 不染（Cover 河图）.txt
# 不沉默的羔羊.txt
# 不离.txt
# 不老梦.txt
# 不良人.txt
# 不见.txt
# 不见有情.txt
# 不见长安.txt
# 不记年.txt
# 不识年岁——《桃花债》系列：宋珧角色歌.txt
# 不负时光.txt
# 不醒梦. 竭泽.txt
# 与君歌.txt
# 与弈惊鸿.txt
# 与归.txt
# 丐秀·无垢.txt
# 且志凌烟.txt
# 且试天下.txt
# 世末歌者（Cover 乐正绫）.txt
# 世界以痛吻我.txt
# 业火苍云歌(纯歌版).txt
# 东京不太热.txt
# 东风志.txt
# 东风第一枝.txt
# 丝路.txt
# 两生契.txt
# 两相负.txt
# 中华美食颂.txt
# 丰碑.txt
# 临安记忆.txt
# 临歧久别歌（纯歌版）——《魔道祖师》群像.txt
# 丹青客.txt
# 丹青客（Cover HITA & 小曲儿）.txt
# 丹青误.txt
# 为你不败.txt
# 为你成全.txt
# 为弦为砚.txt
# 为爱不朽（《不朽凡人》手游主题曲）（Cover 许晓云）.txt
# 为龙.txt
# 主宰.txt
# 乌篷谣.txt
# 乌篷谣（《御剑情缘》主题曲）.txt
# 乌衣巷.txt
# 乐游记.txt
# 乔双花.txt
# 九九八十一.txt
# 九九八十一纯歌版.txt
# 九州撩汉歌.txt
# 九张机（Cover 叶炫清）.txt
# 九歌·东皇太一.txt
# 九鼎天下.txt
# 也许再见.txt
# 书情.txt
# 乱世.txt
# 乱世·守殇.txt
# 乱世·无衣.txt
# 乱世王者.txt
# 乱古【剧情版】——《完美世界》同人曲.txt
# 乱古【纯歌版】——《完美世界》同人曲.txt
# 乱舞苍穹——天之痕女声独唱版.txt
# 于归.txt
# 云垂风烟令.txt
# 云巅长歌.txt
# 云归处.txt
# 云梦谣.txt
# 云水谣.txt
# 云水逢.txt
# 云深不归鸿.txt
# 云里江南.txt
# 五百年前.txt
# 五禽戏.txt
# 京物语.txt
# 人民的名义.txt
# 人质（改编）（Cover 信）.txt
# 人间入画.txt
# 人间朝暮.txt
# 人间沙（电影《爵迹》片尾曲）.txt
# 人鱼传说·人鱼之恋.txt
# 他不懂.txt
# 他们说（HB2 叶修）.txt
# 他和他的天下.txt
# 仙侠世界.txt
# 仙凡劫（凡人修真）.txt
# 仙凡恋（凡人修仙2）.txt
# 仙剑·浮生绘.txt
# 仙剑问情(live).txt
# 以剑之名-血薇.txt
# 以剑之名—血薇.txt
# 以魂之契---《灵契》原创同人曲.txt
# 以魂之契——《灵契》原创同人曲.txt
# 以魂之契（《灵契》同人歌）.txt
# 伏云纪.txt
# 伶仃谣.txt
# 似水流年.txt
# 何处似樽前.txt
# 何必诗债换酒钱.txt
# 何而安.txt
# 余生有幸识故人（剑网3十二门派群像）28p男神女神合体版.txt
# 佛说.txt
# 佛说2.txt
# 你是最好的诗人.txt
# 你有没有见过他（Cover 慕容毓）.txt
# 你现在好吗.txt
# 佳人如梦令.txt
# 依山观澜(无念白).txt
# 侠义.txt
# 侠梦.剑锋落拓.txt
# 俗世呀.txt
# 修炼爱情.txt
# 修罗战场.txt
# 俯仰河山.txt
# 倒霉孩子养成日记.txt
# 倚天剑雨.txt
# 倦世间.txt
# 倩音流年.txt
# 倾城.txt
# 倾尽天下.txt
# 倾情天涯.txt
# 倾成之恋.txt
# 偃月流华.txt
# 假如有如果.txt
# 假面.txt
# 停留.txt
# 健康使者.txt
# 催雪忘故.txt
# 傲世九重天.txt
# 儒道至圣.txt
# 元气封神.txt
# 光之舞.txt
# 兔子先生.txt
# 兔子先生（粤语版）（Cover 洛天依）.txt
# 入戏.txt
# 入梦.竹梦令.txt
# 入雪逢春.txt
# 八景八记.txt
# 兰夜.txt
# 兰惜.txt
# 兰若词.txt
# 共谋江山.txt
# 关键词（Cover 林俊杰）.txt
# 兵家·埋骨他乡.txt
# 典狱司.txt
# 典狱司（cover：音频怪物）.txt
# 再见，繁花血景.txt
# 再逢明月照九州.txt
# 凡人歌（Cover 李宗盛）.txt
# 凤于九天.txt
# 凤凰劫.txt
# 凤栖花.txt
# 凤隐天下.txt
# 出塞.txt
# 出道吧！Moonlight.txt
# 出鞘 - 剧情版.txt
# 出鞘——浩气盟战歌【纯歌版】.txt
# 出鞘【剑网3浩气战歌】.txt
# 刀山火海（Mc子龙）.txt
# 刀马旦.txt
# 刚好遇见你.txt
# 刚好遇见你（Cover 李玉刚）.txt
# 初见便是永远.txt
# 别有天.txt
# 别赋.txt
# 刹那芳华曲(圆满版).txt
# 前缘令（Cover 吴琼）.txt
# 剑之道.txt
# 剑啸江湖.txt
# 剑如虹.txt
# 剑心(藏剑).txt
# 剑指风流.txt
# 剑胆.txt
# 剑胆琴心(长歌门) - 纯歌版.txt
# 剑走偏锋.txt
# 剑锋落拓.txt
# 剑饮山河•剧情版.txt
# 勇气 （Cover 梁静茹）.txt
# 勇者无疆.txt
# 化蝶梦令.txt
# 化身孤岛的鲸.txt
# 化龙.txt
# 北风行.txt
# 医者仁心.txt
# 医说.txt
# 十三月凉.txt
# 十世镜.txt
# 十二和春令.txt
# 十二风华鉴.txt
# 十年一晌.txt
# 十年荣光.txt
# 千古.txt
# 千山雪寂-七夜雪.txt
# 千梦 [with. Aki阿杰].txt
# 千梦.txt
# 千樽雪.txt
# 千秋令.txt
# 千秋月别西楚将.txt
# 千金埋骨.txt
# 半生你我.txt
# 半生叹·书绳水山中壁.txt
# 半道英雄-《全职高手》同人曲.txt
# 半道英雄.txt
# 半道英雄（Cover 喜多修平）.txt
# 华胥引.txt
# 华胥梦.txt
# 卑微情书.txt
# 单身狗之歌.txt
# 南山南.txt
# 南方什么时候能供暖？（别名：舔栏杆）（Cover 打首狱门同好会）.txt
# 卧冰听雪.txt
# 危情夜色.txt
# 即春谣-（家歌）.txt
# 却邪.txt
# 卷珠帘.txt
# 历书·诉情.txt
# 原创【十二生肖】.txt
# 原创帝王攻略同人歌《隐绯雪》.txt
# 原点.txt
# 参商(纯歌版).txt
# 又雪.txt
# 友谊之歌.txt
# 双抛桥.txt
# 叙世 With.清弄.txt
# 古旧人间.txt
# 古风2016（人声版）.txt
# 古龙群侠传.txt
# 可念不可说.txt
# 可惜不是你（Cover 梁静茹）.txt
# 司南歌——广播剧《相见欢·银汉飞度》ED性转版.txt
# 司花令.txt
# 同归.txt
# 同归（明教·剑网三）.txt
# 名士自风流.txt
# 君不知.txt
# 君临天下.txt
# 君卿辞.txt
# 君生我未生.txt
# 君臣天下.txt
# 听风无涯 - 翻唱版.txt
# 听风无涯.txt
# 吾生之地.txt
# 吾辈逍遥.txt
# 命中注定.txt
# 命局.txt
# 命悬一线.txt
# 咖喱咖喱（Cover 牛奶咖啡.）.txt
# 咫尺相思 古剑奇谭同人原创.txt
# 哎哟单身狗（Cover 徐梦圆）.txt
# 哪吒.txt
# 哭三变.txt
# 唱一遍一遍（Cover 费玉清）.txt
# 唱于你听.txt
# 啦啦啦德玛西亚.txt
# 啷个哩个啷（Cover：鹏泊）.txt
# 喜欢你的无数个理由.txt
# 噩梦.裂.txt
# 囚龙.txt
# 四人合唱-四重罪孽（Cover 洛天依&乐正绫&言和）.txt
# 四时令.txt
# 四重罪孽.txt
# 回合.txt
# 回归潇洒.txt
# 圈套（《300英雄》游戏主题曲）.txt
# 土拨鼠之歌.txt
# 圣焰瞑影.txt
# 在风里——【恋与制作人白起原创同人歌曲】.txt
# 地狱之火【王者荣耀孙悟空同人歌】.txt
# 墨宝 古龙群侠传.txt
# 墨宝 终章.txt
# 墨泪.txt
# 墨衣.txt
# 夏目的美丽日记.txt
# 夕山谣.txt
# 外婆桥（Cover 初音ミク）.txt
# 外婆的话【不才】.txt
# 多幸运（Cover 韩安旭.）.txt
# 夜中笺·无题.txt
# 夜行黑白路（《阴阳师》鬼使黑白同人曲）.txt
# 夜雨陈酒.txt
# 大圣.txt
# 大小姐和大少爷的反派生涯（Cover 洛天依）.txt
# 大浪淘沙.txt
# 大王叫我来巡山.txt
# 大荒往事.txt
# 大风起兮.txt
# 大鱼(徐梦圆Remix).txt
# 大鱼  （Cover 周深）.txt
# 大黄小黄和老黄.txt
# 天下为棋.txt
# 天下第一.txt
# 天之禁.txt
# 天地无疆.txt
# 天地缓缓(纯阳).txt
# 天墉记年.txt
# 天字十三杀.txt
# 天涯 (Live版).txt
# 天涯.txt
# 天涯三唱.txt
# 天涯有蔷薇.txt
# 天策枪魂.txt
# 天若灵犀.txt
# 天行健.txt
# 天边外.txt
# 失空斩.txt
# 女孩你为何踮脚尖.txt
# 奸雄.txt
# 她.txt
# 好好 （Cover 五月天）.txt
# 好梦如旧.txt
# 如初见.txt
# 如意.txt
# 如果我们不曾相遇（Cover 五月天）.txt
# 如果有来生.txt
# 如花.txt
# 妖怪町奇谭.txt
# 妹在江边洗茼蒿.txt
# 妻书.txt
# 姑苏客.txt
# 子衿.txt
# 孤剑江湖.txt
# 孤城.txt
# 孤芳.txt
# 学不会（Cover 林俊杰）.txt
# 守候--《花语学园》宣传曲.txt
# 守望.txt
# 宝贝，回家.txt
# 客从远方来.txt
# 客官请进【少司命】.txt
# 宣.txt
# 宫心.txt
# 家国天下.txt
# 家国天下 — 记秦时明月聂蓉.txt
# 宿命.txt
# 寄我此生.txt
# 寒夜词.txt
# 寒江雪.txt
# 寒衣调.txt
# 寒衫浮梦.txt
# 寸山河.txt
# 寸缕.txt
# 对不起我爱你.txt
# 对弈.txt
# 对黄昏.txt
# 寻鹿.txt
# 小丑的品格（Cover 泠鸢yousa）.txt
# 小半 重编曲版.txt
# 小小.txt
# 小尘寰.txt
# 小时候.txt
# 小棋童 （Cover 不纯君）.txt
# 小灯泡【剧情版】.txt
# 小狐狸.txt
# 小精灵.txt
# 小跳蛙（Cover 青蛙乐队）.txt
# 少年中国.txt
# 少年时.txt
# 少年游.txt
# 尘埃.txt
# 屠苏.txt
# 山之高.txt
# 山僧.txt
# 山居.txt
# 山居谣.txt
# 山川挽歌（Cover：完美仙剑）.txt
# 山有木兮-橙光《人鱼传说之长生烛》主题曲.txt
# 山水画意.txt
# 山水闲人.txt
# 山河人间【剧情版】.txt
# 山河人间【纯歌版】.txt
# 山河永慕.txt
# 山海侧.txt
# 山脉 .txt
# 山雨.txt
# 山鬼.txt
# 岁寒三友.txt
# 岁晚.txt
# 岁月成碑.txt
# 岁月神偷.txt
# 岁神祭.txt
# 岁闲青山.txt
# 峨眉.txt
# 希求.txt
# 帝梦.执天之行.txt
# 干物女.txt
# 平安奇妙物语（《阴阳师》半年庆宣传曲）.txt
# 并辔.txt
# 幸为天下客.txt
# 幻境.txt
# 序章.txt
# 应思量(NPC群像).txt
# 应许之心.txt
# 应许之心——《恋与制作人》许墨同人曲.txt
# 底比斯记忆.txt
# 异世谣·万世芬芳录.txt
# 弃剑相随.txt
# 弈剑听雨阁.txt
# 归.txt
# 归客天涯·魔道祖师群像.txt
# 归来.txt
# 归零.txt
# 当归(万花&天策).txt
# 当战——剑网3竞技大师赛·官方宣传曲.txt
# 当然是选择原谅她.txt
# 当然是选择原谅她啊（Cover 洛天依）.txt
# 影武.txt
# 御剑天涯（《御剑情缘》周年主题曲）.txt
# 御华万里 crossfade.txt
# 御歌行.txt
# 御龙吟-翻唱.txt
# 心不择言.txt
# 心做し（Cover GUMI）.txt
# 必入歧途.txt
# 忆作霜飞去.txt
# 忘川.txt
# 忘记(广播剧《墓门》ED).txt
# 快活（Cover 琉辉）.txt
# 忽如远行客.txt
# 忽梦少年事.txt
# 恋语——【恋与制作人同人曲】（Cover 萧忆情）.txt
# 恋音と雨空（cover AAA）.txt
# 恣意江湖.txt
# 息兮.txt
# 恰逢暮雪亦白头.txt
# 悟空.txt
# 悬空.txt
# 悼英雄【剧情版】（Cover Rin）.txt
# 情千劫.txt
# 情囚.txt
# 情梦孤祭.txt
# 情歌王.txt
# 情藏.txt
# 情醉.txt
# 惊鸿一面.txt
# 惜言.txt
# 想家.txt
# 愿君安（Cover 松下奈绪）.txt
# 憾长情 (剧情版).txt
# 戏子说.txt
# 戏楼.txt
# 戏精.txt
# 戏语花（Cover 《寒江雪》郑源）.txt
# 戏里春秋戏外听.txt
# 成佛.txt
# 成全（改版）（Cover 林宥嘉）.txt
# 我与自己唱相守.txt
# 我们结婚吧（Cover 丁于）.txt
# 我住长江头.txt
# 我叫奶瓶.txt
# 我可不可以选你（Cover One Direction）.txt
# 我在人民广场吃炸鸡（Cover 赵大格）.txt
# 我多喜欢你，你会知道（Cover 王俊琪）.txt
# 我好像在哪见过你（Cover：薛之谦）.txt
# 我心上住着一座长安城（剧情版）.txt
# 我执.txt
# 我最亲爱的（纯女声）.txt
# 我的一个道姑朋友（Cover Lon）.txt
# 我的世界.txt
# 我的天空 （Cover 南征北战）.txt
# 我的楼兰新娘.txt
# 我笔写我心.txt
# 战争世界.txt
# 战国杀.txt
# 战惊天下.txt
# 扇子舞.txt
# 执笔——致青海草原.txt
# 扬州一日游.txt
# 扬州姑娘.txt
# 承剑.txt
# 承剑（《古剑OL》门派群像）.txt
# 承君.txt
# 承欢殿.txt
# 拂世之剑.txt
# 拂雪.txt
# 拾念.txt
# 拿走了什么.txt
# 挑兰灯.txt
# 捕梦.txt
# 换世奇恋.txt
# 提剑来邀红尘客（Cover 桜音）.txt
# 摆渡.txt
# 撒野（Cover 欸-61）.txt
# 故人.txt
# 故人叹（Cover 吴琼）.txt
# 故园情.txt
# 故城.txt
# 故时月色.txt
# 故梦.txt
# 故梦（Cover 橙翼）.txt
# 敘世.txt
# 散场.txt
# 数羊.txt
# 新一代的开山怪.txt
# 新诛仙.情醉.txt
# 旁观者S的独白.txt
# 旅ダチノウタ.txt
# 无关风月.txt
# 无双.txt
# 无垢 - 纯歌版.txt
# 无寄.txt
# 无归（Cover 叶里）.txt
# 无故之秋.txt
# 无碑人.txt
# 无端相忆.txt
# 无脚鸟.txt
# 无问（Cover 毛不易）.txt
# 日暮归途.txt
# 旧梦.txt
# 旱獭之歌（《GON的旱獭》第二季主题曲）.txt
# 时光情书.txt
# 时空之间（《300英雄》主题曲）.txt
# 明暗.txt
# 明月天涯.txt
# 明月如霜.txt
# 明月舟.txt
# 明月谱.txt
# 明月逐人归.txt
# 明朝传奇.txt
# 昔言.txt
# 星耀恋曲.txt
# 星辰变.txt
# 春宴如旧.txt
# 春归.txt
# 春意红包.txt
# 春梦.月落春荒.txt
# 春江花月夜.txt
# 春风一顾.txt
# 春风夏雨.txt
# 是我乎.txt
# 是风动.txt
# 晓秋月明.txt
# 普通disco.txt
# 普通的Disco.txt
# 晴川雪.txt
# 晴雪夜 (纯歌版).txt
# 暗恋.txt
# 暮光.txt
# 暮雪.txt
# 曲无忆之独立寒江.txt
# 最是李商隐.txt
# 最极限（超智能足球）.txt
# 最长的旅途 .txt
# 最长的电影.txt
# 月上瓜洲.txt
# 月光.txt
# 月出.txt
# 月华沉梦.txt
# 月弯弯.txt
# 月弯弯（Cover 贰婶）.txt
# 月照京华.txt
# 月琢.txt
# 月赋情长.txt
# 有一封信.txt
# 有一种爱叫做放手.txt
# 有何不可(English Ver.).txt
# 有幸遇到你（HB2 叶修）.txt
# 有所思(剧情版).txt
# 有涯 — 天涯明月刀OL七门派群像.txt
# 望乡台.txt
# 朝暮人间客.txt
# 未曾辞故人 - （记云梦双杰）.txt
# 未曾辞故人——《魔道祖师》同人曲.txt
# 末路疏狂.txt
# 朱砂泪.txt
# 朱颜偕.txt
# 杀伐(恶人谷).txt
# 杀伐.txt
# 杀伐——剧情版【剑网3恶人谷阵营歌】.txt
# 杀伐【剧情版】——《剑网三》恶人谷战歌.txt
# 杀伐【纯歌版】——《剑网三》恶人谷战歌.txt
# 杀手.txt
# 杀马特遇见洗剪吹.txt
# 权御天下.txt
# 权御天下18P.txt
# 权香调.txt
# 杏花天.txt
# 杯酒覆长风——记兰陵王高长恭.txt
# 杯酒释兵权.txt
# 松烟入墨.txt
# 松窗棋罢.txt
# 果汁分你一半（Cover 花儿乐队）.txt
# 枫.txt
# 枯荣 .txt
# 柒寒.txt
# 标准普通话甲.txt
# 栖枝.txt
# 桂棹兰桨.txt
# 桃园三国.txt
# 桃花何归.txt
# 桃花别处起长歌.txt
# 桃花笑（Cover 洛天依、言和、乐正凌）.txt
# 桃花醉.txt
# 桃花错.txt
# 梅坞寻茶.txt
# 梅子黄尽时.txt
# 梦中的芳华.txt
# 梦回九龙朝（九龙朝）.txt
# 梦太晚.txt
# 梦望断.txt
# 梦蝶.txt
# 梦见.txt
# 梦遣看花人.txt
# 梦里偕老.txt
# 梦里梨花白.txt
# 梦里水乡.txt
# 梦里谁知身是客.txt
# 梦间集.txt
# 棋客.txt
# 棠梨煎雪.txt
# 棠梨煎雪（Cover 银临）.txt
# 棠花谢.txt
# 楚狂.txt
# 樟木巷.txt
# 樱散零乱.txt
# 樱花樱花想见你.txt
# 樱花樱花想见你（Cover 高野健一）.txt
# 樱花草.txt
# 橙·江月风.txt
# 欠一个拥抱.txt
# 歌声のキセキ【以歌为迹】.txt
# 此处长安.txt
# 此生眷恋.txt
# 此生负心只一人.txt
# 此生长.txt
# 此间情长.txt
# 歪歪？.txt
# 死肥宅之歌.txt
# 殊宠（Cover 河图）.txt
# 殿前欢.txt
# 水墨江南.txt
# 水龙吟.txt
# 永恒英雄曲（《300英雄》主题曲）.txt
# 氹氹转.txt
# 江南伤.txt
# 江南叹.txt
# 江南恋.txt
# 江南梦.txt
# 江南调.txt
# 江南雨.txt
# 江山如梦.txt
# 江山雪(纯阳).txt
# 江山雪.txt
# 江湖.txt
# 江湖大梦.txt
# 江湖归来叙旧茶.txt
# 江秋已过.txt
# 江雪埋骨.txt
# 沧海一声笑.txt
# 沧海之曜.txt
# 油纸伞.txt
# 泡沫.txt
# 泸沽寻梦 （Cover 银临）.txt
# 洒拓歌.txt
# 流年兮.txt
# 流萤如星.txt
# 流觞曲水.txt
# 浮云生死.txt
# 浮生散尽 - 剧情版.txt
# 浮生未歇.txt
# 浮生若梦.txt
# 浮生辞.txt
# 浮食烩.txt
# 海棠.txt
# 海棠酒满.txt
# 海绵宝宝.txt
# 涉川.txt
# 深海少女（Cover MIKU）.txt
# 清明上河图.txt
# 清明上河笑.txt
# 清欢怅.txt
# 清歌流觞.txt
# 清风未老.txt
# 清风知我意.txt
# 湖光水色调.txt
# 湖心亭.txt
# 湘桥月.txt
# 溯世书.txt
# 满城雪（燃情版）——《梦幻西游》电脑版剑侠客同人曲.txt
# 潜别离.txt
# 瀘沽寻梦.txt
# 灯暖衣轻.txt
# 灯暖衣轻 .txt
# 灵契.txt
# 灵秀.txt
# 灵魂摆渡.txt
# 灼.txt
# 炜爱出道.txt
# 炸鸡之歌.txt
# 烈火 (剧情版).txt
# 烈火——盗墓笔记群像同人歌.txt
# 烛花红.txt
# 烟影如画.txt
# 烟火莲灯.txt
# 烟笼长安.txt
# 烟雨.txt
# 烟雨行舟.txt
# 烟雨迷离.txt
# 热爱至上.txt
# 燃尽人间色.txt
# 爱即正义.txt
# 爱在西元前.txt
# 爱如空气.txt
# 爱殇.txt
# 爱殇（Cover：小时姑娘）.txt
# 牵丝戏.txt
# 牵机(唐毒).txt
# 牵绊.txt
# 狐仙之淀川情.txt
# 狐荼.txt
# 狐言.txt
# 独立.txt
# 独立寒江·曲无忆.txt
# 独酌.txt
# 献天缘.txt
# 王者【王者荣耀群像同人歌】.txt
# 琅琊榜2同人歌曲《愿为同命鸟》.txt
# 琅琊榜·祭忠魂.txt
# 琅琊榜·赤血长殷.txt
# 琅琊榜【别故人】.txt
# 理想三旬（Cover 陈鸿宇）.txt
# 琉璃色（九功舞官方主题曲）.txt
# 琴师.txt
# 琴师（Cover 音频怪物）.txt
# 琴师（cover：音频怪物） - 粤语版.txt
# 瑶琴【少司命】.txt
# 生如逆旅(剧情版).txt
# 生旦净末丑.txt
# 生死劫.txt
# 生死梦. 连枝冢.txt
# 生死簿.txt
# 画壁 - 管弦编曲版.txt
# 画诗.txt
# 疾风剑豪.txt
# 病名为爱（Cover 镜音双子）.txt
# 白头吟.txt
# 白素贞.txt
# 白色森林.txt
# 白虹贯日.txt
# 白衣.txt
# 百鬼夜行.txt
# 百鬼阴阳抄-柔情版.txt
# 百鬼阴阳抄.txt
# 皆斩--剑网三·恶人谷.txt
# 皈依.txt
# 皋之鲤.txt
# 盗墓笔记 流离 - 无念白.txt
# 盗墓笔记·张起灵·不朽.txt
# 盗墓笔记·无邪.txt
# 盛世回首.txt
# 直面丑陋的自己.txt
# 相守.txt
# 相思.txt
# 相思又一年.txt
# 相思局.txt
# 相思引.txt
# 相思碑.txt
# 相见欢.txt
# 相认.txt
# 眉如远山.txt
# 眉如远山 Ft.云の泣.txt
# 眉间雪.txt
# 眉间雪（Cover 晴愔）.txt
# 知与君同.txt
# 知了的歌.txt
# 石楠小札.txt
# 破晓将至.txt
# 碧海潮生曲（神雕侠侣）.txt
# 礼仪之邦.txt
# 神武笑春风（神武）.txt
# 神经病之歌.txt
# 神通.txt
# 禅茶一味（念白版）——记陆羽皎然.txt
# 离人愁（Cover 曲肖冰）.txt
# 离人（Cover 林志炫）.txt
# 离骚.txt
# 秋水.txt
# 秋风知月明.txt
# 秦淮八艳-群像（Cover：玉璇玑）.txt
# 秦淮八艳.txt
# 秦风·唱山河.txt
# 空.txt
# 窗前明月光.txt
# 童话镇（Cover 暗杠）.txt
# 竹枝词.txt
# 笑红尘.txt
# 笔墨山河千秋色.txt
# 笔墨稠.txt
# 笔底知交（Cover KBShinya&哦漏）.txt
# 第三十八年夏至.txt
# 第三十八年夏至（cover：河图）.txt
# 等待的沉默（诛仙2）.txt
# 答应我（Cover AKB48）.txt
# 算命小司.txt
# 粉红色的回忆.txt
# 红妆.txt
# 红妆天下.txt
# 红尘.txt
# 红尘无涯-橙光《再世为仙》主题曲.txt
# 红尘无涯——橙光《再世为仙》主题曲.txt
# 红颜.txt
# 红颜旧.txt
# 红颜若雪.txt
# 纯白.txt
# 纯阳寞.txt
# 纵痴也狂.txt
# 纵马长歌.txt
# 纸短情长（Cover 烟把儿乐队）.txt
# 终岁风流人.txt
# 结庐朝暮间.txt
# 结绳踏歌.txt
# 绝世 古龙群侠 大合唱.txt
# 绝地反击（超智能足球）.txt
# 绿·山水吟.txt
# 缘.txt
# 缘尽世间.txt
# 缘无归期.txt
# 缘生意转.txt
# 缺席.txt
# 罪章残像.txt
# 翩跹.txt
# 老画家.txt
# 老酒街.txt
# 肚兜.txt
# 胭脂雪.txt
# 腐草为萤.txt
# 腐草为萤（Cover 银临）.txt
# 自卑（Cover 吴浩康）.txt
# 自在 —— 手游《太乙仙魔录之灵飞纪》同人曲.txt
# 艳唐.txt
# 艳夜行【阴阳师SSR群像】.txt
# 芈月传·摽有梅.txt
# 芊芊(女生版).txt
# 花凋.txt
# 花千骨之Dearest梦.txt
# 花开不记年.txt
# 花开十三月.txt
# 花想容.txt
# 花旦.txt
# 花枝春野.txt
# 花神泪.txt
# 花间事.txt
# 花间旧事.txt
# 花间辞.txt
# 花鸟卷（“阴阳师”手游花鸟卷同人歌）.txt
# 芳华旧.txt
# 苍山负雪.txt
# 苍穹变.txt
# 苔山翁.txt
# 若某日我封笔.txt
# 若相惜.txt
# 茉莉香片.txt
# 茶道.txt
# 荔枝春.txt
# 荣耀.征途.txt
# 荣耀与你.txt
# 荣耀降临.txt
# 莛瀛.txt
# 莫唱无情歌——魔道祖师同人曲.txt
# 莫问归处 - 纯歌版.txt
# 莫问归处·倩女幽魂2.txt
# 莲华错·梵音.txt
# 菁华浮梦.txt
# 菩萨蛮.txt
# 落幕.txt
# 落笔应风雨.txt
# 落花情.txt
# 落花时节又逢君.txt
# 落长安.txt
# 落霞云归.txt
# 葬春.txt
# 葬歌.txt
# 葬花吟.txt
# 蒹葭.txt
# 蓝·也无风雨.txt
# 蓬蒿行.txt
# 蔚蓝之海.txt
# 薛涛笺.txt
# 藏.txt
# 藏剑·一叶.txt
# 藏龙.txt
# 虹之间.txt
# 蜀·御风.txt
# 蜀·御风 - 剧情版（三国之蜀汉群像）.txt
# 蜀·御风 - 纯歌版（三国之蜀汉群像）.txt
# 蜀道难.txt
# 蝶梦翩跹.txt
# 血河之上.txt
# 行月.txt
# 行者万里（记《大圣归来》）.txt
# 衔蝉.txt
# 西塘夜话.txt
# 西狂（神雕侠侣）.txt
# 西瓜Jun - 狂野想乡-双声道（左瓜右排）.txt
# 西窗.txt
# 覆雨.txt
# 见南山.txt
# 觅.txt
# 解语红妆冷·迟语.txt
# 让泪化作相思雨.txt
# 诗.txt
# 该死的温柔.txt
# 误芳瑶.txt
# 说余梦.txt
# 说散就散（Cover 袁娅维）.txt
# 诸子百家.txt
# 诺言老.txt
# 谁与无疆.txt
# 调笑令.txt
# 谈杯.txt
# 谓我.txt
# 谓风.txt
# 谢却荼蘼.txt
# 谢谢陌生的你.txt
# 贝加尔湖畔.txt
# 贺新谣.txt
# 赤·骄阳如我.txt
# 赤水谣.txt
# 赤血长殷.txt
# 赴鸿门.txt
# 起灵.txt
# 起风了（Cover 买辣椒也用券）.txt
# 起风了（Cover 高橋優）.txt
# 起飞·角色歌.txt
# 路过世界的旅行家 （Be 填词）.txt
# 踏歌逐梦.txt
# 身体健康（Cover 张卫健）.txt
# 轻轻的告诉你.txt
# 返璞归贞.txt
# 还不是因为你长得不好看.txt
# 还行.txt
# 这尘世多谢你降临——书海沧生写文十周年庆.txt
# 迷迭香.txt
# 追光者（Cover 岑宁儿）.txt
# 追梦.夏虫语冰.txt
# 适居山.txt
# 逆世成局.txt
# 逆光.txt
# 逆流.txt
# 逆浪千秋（Cover 言和）.txt
# 逆风.txt
# 选择困难症——《恋与制作人》四男主同人曲.txt
# 逍遥无穷.txt
# 逍遥游.txt
# 逐世行 - 纯歌.txt
# 逐世行 - （剧情版）.txt
# 遇到恶作剧（Cover 王蓝茵）.txt
# 遇见（Cover 孙燕姿）.txt
# 遮天.txt
# 那一天从梦中醒来.txt
# 都市惊奇夜-《中国惊奇先生》手游主题曲.txt
# 醉仙歌.txt
# 醉寒江(剧情版).txt
# 醉梦仙霖 (Live版).txt
# 醉梦仙霖.txt
# 醉江湖.txt
# 醉沙场.txt
# 醉话江湖.txt
# 醉逍遥.txt
# 醉里挑灯看剑.txt
# 醉里相思 .txt
# 采茶纪.txt
# 采薇.txt
# 野子.txt
# 金陵秦淮夜.txt
# 金风玉露.txt
# 铜雀赋.txt
# 错付旧梦.txt
# 错梦.txt
# 锦瑟长思.txt
# 锦鲤抄 (live版).txt
# 锦鲤抄.txt
# 镜花水月.txt
# 长安乱.txt
# 长安幻夜-安碧城(剧情版).txt
# 长安幻夜·安碧城(纯歌版).txt
# 长安忆.txt
# 长恨歌.txt
# 长恨歌第一章.txt
# 长歌——《长歌行》李长歌角色歌.txt
# 长生诀.txt
# 长相忆.txt
# 长绝.txt
# 闪电（超智能足球）.txt
# 问剑江湖.txt
# 问月——《秦时明月》同人曲.txt
# 问琴.txt
# 问酒谢花.txt
# 闰猹抄.txt
# 闲云志.txt
# 闲时灯照月.txt
# 闻说.txt
# 阙行成双.txt
# 阳关调.txt
# 阳山绝（Cover 洛天依&乐正绫）.txt
# 阴阳先生.txt
# 陈情——《魔道祖师》同人曲（Cover 侧田）.txt
# 陌上花开.txt
# 陌上花开（Cover 小爱的妈）.txt
# 陌上花早.txt
# 陪你到世界尽头.txt
# 陶然四季.txt
# 随想.txt
# 隐.txt
# 隔世信(七秀&少林).txt
# 隔烟水（Cover 晃儿）.txt
# 障月.txt
# 雁公子.txt
# 雁城雪.txt
# 雕花笼.txt
# 雨巷.txt
# 雨霖铃.txt
# 雪与弦.txt
# 雪海香梅尽(《倾世皇妃》插曲).txt
# 雪诉离歌.txt
# 霁夜茶.txt
# 霜降·雁归.txt
# 霜雪千年.txt
# 露中生.txt
# 霸者无双.txt
# 青原樱（Cover 人衣大人）.txt
# 青城山下白素贞—翻唱好妹妹乐队《青城山下白素贞》.txt
# 青山入我怀.txt
# 青山揽梦.txt
# 青梅竹马.txt
# 青玉案（唱：云の泣 词：小鱼萝莉）.txt
# 青龙永夜.txt
# 静默温存.txt
# 非酋の日常.txt
# 非鱼(少林&纯阳).txt
# 韶华与共.txt
# 风华录.txt
# 风华燃尽-指间砂.txt
# 风月.txt
# 风沙客.txt
# 风缘.txt
# 风花雪月.txt
# 风萤月.txt
# 风起天阑.txt
# 风雪洗剑.txt
# 飞羽.txt
# 飞雪与剑.txt
# 饮水一梦.txt
# 饮马江湖风萧萧.txt
# 马步谣.txt
# 马步谣（男声版）（Cover 双笙）.txt
# 鬼医.txt
# 魂嫁 With.莲琊.txt
# 魂归(天策).txt
# 魅影醉.txt
# 魔道·同道且同归.txt
# 鲛人之遇鳞.txt
# 鸿崖之末 （钟无艳填词）.txt
# 鸿鹄志.txt
# 鹃.txt
# 鹫岭檐(歌曲版).txt
# 鹰旗.txt
# 麒麟.txt
# 黄·酒仙行.txt
# 黑暗鸢尾.txt
# 黑白.txt
# 黑白小巷.txt
# 默.txt
# 默契.txt
# 黯然销魂.txt

# %%
with open("./all_5.txt", 'a', encoding='utf8') as w:
    lines = f.readlines()
    for line in lines:
        for char in line:
            if char=='【】':
